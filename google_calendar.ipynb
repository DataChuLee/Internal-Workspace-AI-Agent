# %% [markdown]
# ### Google Calendar API 연동
# - Google Calendar에 대한 학습보다는 Function Call 기능을 위한 Function 이해도 증가 목적
#
# - Google Calendar API 셋업 필요
#   - https://developers.google.com/calendar/api/quickstart/python?hl=ko
#   - 위 가이드를 따라가도 되지만 아래 직접 작성한 API 셋업 방법 참고하시는 것을 권장

# %% [markdown]
# ### Google Calendar API 셋업 방법
# 1. Google Cloud Project 생성
#     - https://console.cloud.google.com/projectcreate
# 2. Google Calendar API 사용 설정 및 API Key 발급
#     - 라이브러리 > Calendar 검색 > Google Calendar "사용" 설정
#         - https://console.cloud.google.com/flows/enableapi?apiid=calendar-json.googleapis.com&hl=ko
#     - 메뉴 > API 및 서비스 > 사용자 인증 정보 > 사용자 인증 정보 만들기 > API 키 (*공식 가이드엔 이 내용이 없음)
# 3. OAuth 동의 화면 생성 및 테스트 유저에 본인 추가
#     - 메뉴 > OAuth 동의 화면
#         - User Type: 외부 > 만들기
#         - 필수 항목 작성
#     - 범위 추가
#         - .../auth/calendar.events.owned > 업데이트
#     - 테스트 사용자로 본인 추가
# 4. OAuth Client ID 생성
#     - 메뉴 > 사용자 인증 정보 > 사용자 인증 정보 만들기 > OAuth 클라이언트 ID
#     - 애플리케이션 유형: 데스크톱 앱
#     - "OAuth 클라이언트 생성됨" 화면이 뜨면 JSON 다운로드 버튼 클릭
#     - 다운로드 받은 파일을 ./res/credentials.json으로 저장

# %% [markdown]
# ### 잘 진행되었다면 아래 코드가 정상적으로 수행되어야 함
# - 구글 계정 로그인 후 "Google에서 확인하지 않은 앱 - 현재 테스트 중인 앱에 대한 액세스 권한을 받았습니다" 내용
#   - 계속 버튼 클릭
# - 이 확인 프로세스는 첫 1회만 수행 (아래 코드가 ./res/token.json 저장 후 자동 인증)

# %%
import os.path

from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build


SCOPES = ["https://www.googleapis.com/auth/calendar"]


# 만약 invalid_grant: Token has been expired or revoked 에러 발생 시 ./res/token.json을 지우고 다시 코드 실행해서 ./res/token.json 재생성
if os.path.exists("./res/token.json"):
    creds = Credentials.from_authorized_user_file("./res/token.json", SCOPES)
else:
    flow = InstalledAppFlow.from_client_secrets_file("./res/credentials.json", SCOPES)
    creds = flow.run_local_server(port=0)
    with open("./res/token.json", "w") as token:
        token.write(creds.to_json())

service = build("calendar", "v3", credentials=creds)
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=745724411728-ffqr2pd40t4v4eqi06d3jvsq4jhq6kqs.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A58935%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcalendar&state=VeAHLF3voVxmkfRX2nhEFnfEvZlItO&access_type=offline

# %% [markdown]
# ### 캘린더 일정 생성

# %%
event = {
    "summary": "Meeting",
    "location": "서울특별시 동대문구 이문로 7 B102 샤갈의마을",
    "start": {
        "dateTime": "2026-02-06T16:00:00+09:00",
        "timeZone": "Asia/Seoul",
    },
    "end": {
        "dateTime": "2026-02-06T18:00:00+09:00",
        "timeZone": "Asia/Seoul",
    },
}

event = service.events().insert(calendarId="primary", body=event).execute()
print("Event created: %s" % (event.get("htmlLink")))
# Out:
# Event created: https://www.google.com/calendar/event?eid=aGE0dWg2ZXU2bjJtZG1lbTBuM3BlYnFpcDQgcWFzZDIwMjE5QG0

# %%
event
# Out:
# {'kind': 'calendar#event',
#  'etag': '"3540570520625214"',
#  'id': 'ha4uh6eu6n2mdmem0n3pebqip4',
#  'status': 'confirmed',
#  'htmlLink': 'https://www.google.com/calendar/event?eid=aGE0dWg2ZXU2bjJtZG1lbTBuM3BlYnFpcDQgcWFzZDIwMjE5QG0',
#  'created': '2026-02-05T09:54:20.000Z',
#  'updated': '2026-02-05T09:54:20.312Z',
#  'summary': 'Meeting',
#  'location': '서울특별시 동대문구 이문로 7 B102 샤갈의마을',
#  'creator': {'email': 'qasd20219@gmail.com', 'self': True},
#  'organizer': {'email': 'qasd20219@gmail.com', 'self': True},
#  'start': {'dateTime': '2026-02-06T16:00:00+09:00', 'timeZone': 'Asia/Seoul'},
#  'end': {'dateTime': '2026-02-06T18:00:00+09:00', 'timeZone': 'Asia/Seoul'},
#  'iCalUID': 'ha4uh6eu6n2mdmem0n3pebqip4@google.com',
#  'sequence': 0,
#  'reminders': {'useDefault': True},
#  'eventType': 'default'}

# %% [markdown]
# ### 캘린더 일정 조회

# %%
calendar_id = "primary"
time_min = "2026-02-06T00:00:00+09:00"
time_max = "2026-02-06T23:59:59+09:00"
max_results = 5
is_single_events = True
orderby = "startTime"

events_result = (
    service.events()
    .list(
        calendarId=calendar_id,
        timeMin=time_min,
        timeMax=time_max,
        maxResults=max_results,
        singleEvents=is_single_events,
        orderBy=orderby,
    )
    .execute()
)

# %%
events_result
# Out:
# {'kind': 'calendar#events',
#  'etag': '"p33fplie9hb1940o"',
#  'summary': 'qasd20219@gmail.com',
#  'description': '',
#  'updated': '2026-02-05T09:54:38.842Z',
#  'timeZone': 'Asia/Seoul',
#  'accessRole': 'owner',
#  'defaultReminders': [{'method': 'popup', 'minutes': 30}],
#  'items': [{'kind': 'calendar#event',
#    'etag': '"3540570520625214"',
#    'id': 'ha4uh6eu6n2mdmem0n3pebqip4',
#    'status': 'confirmed',
#    'htmlLink': 'https://www.google.com/calendar/event?eid=aGE0dWg2ZXU2bjJtZG1lbTBuM3BlYnFpcDQgcWFzZDIwMjE5QG0',
#    'created': '2026-02-05T09:54:20.000Z',
#    'updated': '2026-02-05T09:54:20.312Z',
#    'summary': 'Meeting',
#    'location': '서울특별시 동대문구 이문로 7 B102 샤갈의마을',
#    'creator': {'email': 'qasd20219@gmail.com', 'self': True},
#    'organizer': {'email': 'qasd20219@gmail.com', 'self': True},
#    'start': {'dateTime': '2026-02-06T16:00:00+09:00',
#     'timeZone': 'Asia/Seoul'},
#    'end': {'dateTime': '2026-02-06T18:00:00+09:00', 'timeZone': 'Asia/Seoul'},
#    'iCalUID': 'ha4uh6eu6n2mdmem0n3pebqip4@google.com',
#    'sequence': 0,
#    'reminders': {'useDefault': True},
#    'eventType': 'default'}]}

# %% [markdown]
# ### 캘린더 일정 삭제

# %%
event = service.events().delete(calendarId="primary", eventId=event["id"]).execute()
print("Event deleted")
# Out:
# Event deleted

# %%
event
# Out:
# ''
